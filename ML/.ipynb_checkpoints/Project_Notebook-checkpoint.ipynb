# %% [markdown]
# # Solar Power Generation analysis
#
# ## Team Members
# ### 1.Ashish Chauhan
# ### 2.Akash Kumar Gaud
# ### 3.Anish Chauhan
# ### 4.Ashish Gautam
# ### 5.Aryan Shrikant Jadhao

# %% [markdown]
# # Step 1. Data importing and preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#imported the csv file

df=pd.read_csv("powerPlantDataBerkeley.csv")
df.head(10)
# Out:
#    Day of Year  Year  Month  Day  First Hour of Period  Is Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
# 5          245  2008      9    1                    16         True
# 6          245  2008      9    1                    19         True
# 7          245  2008      9    1                    22        False
# 8          246  2008      9    2                     1        False
# 9          246  2008      9    2                     4        False
#
#    Distance to Solar Noon  Average Temperature (Day)  \
# 0                0.859897                         69
# 1                0.628535                         69
# 2                0.397172                         69
# 3                0.165810                         69
# 4                0.065553                         69
# 5                0.296915                         69
# 6                0.528278                         69
# 7                0.759640                         69
# 8                0.862113                         72
# 9                0.630155                         72
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# 2                            28                       7.5          0
# 3                            28                       7.5          0
# 4                            28                       7.5          0
# 5                            28                       7.5          0
# 6                            28                       7.5          0
# 7                            28                       7.5          0
# 8                            29                       6.8          0
# 9                            29                       6.8          0
#
#    Visibility  Relative Humidity  Average Wind Speed (Period)  \
# 0        10.0                 75                          8.0
# 1        10.0                 77                          5.0
# 2        10.0                 70                          0.0
# 3        10.0                 33                          0.0
# 4        10.0                 21                          3.0
# 5        10.0                 20                         23.0
# 6        10.0                 36                         15.0
# 7        10.0                 49                          6.0
# 8        10.0                 67                          6.0
# 9        10.0                 49                          0.0
#
#    Average Barometric Pressure (Period)  Power Generated
# 0                                 29.82                0
# 1                                 29.85                0
# 2                                 29.89             5418
# 3                                 29.91            25477
# 4                                 29.89            30069
# 5                                 29.85            16280
# 6                                 29.83              515
# 7                                 29.86                0
# 8                                 29.86                0
# 9                                 29.87                0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Day of Year                           2920 non-null   int64
#  1   Year                                  2920 non-null   int64
#  2   Month                                 2920 non-null   int64
#  3   Day                                   2920 non-null   int64
#  4   First Hour of Period                  2920 non-null   int64
#  5   Is Daylight                           2920 non-null   bool
#  6   Distance to Solar Noon                2920 non-null   float64
#  7   Average Temperature (Day)             2920 non-null   int64
#  8   Average Wind Direction (Day)          2920 non-null   int64
#  9   Average Wind Speed (Day)              2920 non-null   float64
#  10  Sky Cover                             2920 non-null   int64
#  11  Visibility                            2920 non-null   float64
#  12  Relative Humidity                     2920 non-null   int64
#  13  Average Wind Speed (Period)           2919 non-null   float64
#  14  Average Barometric Pressure (Period)  2920 non-null   float64
#  15  Power Generated                       2920 non-null   int64
# dtypes: bool(1), float64(5), int64(10)
# memory usage: 345.2 KB

# %% [markdown]
# * As clearly visible the dataset is a time series dataset but I didn't sort it because it was already sorted.
# * Secondly there are no columns with object type values hence there was no need of converting any column to pandas category and assigning the codes back to column to convert object type column to numeric type

# %% [markdown]
# ## EDA(Exploratory data analysis)

# %%
df[df.duplicated(keep="first")]
# Out:
# Empty DataFrame
# Columns: [Day of Year, Year, Month, Day, First Hour of Period, Is Daylight, Distance to Solar Noon, Average Temperature (Day), Average Wind Direction (Day), Average Wind Speed (Day), Sky Cover, Visibility, Relative Humidity, Average Wind Speed (Period), Average Barometric Pressure (Period), Power Generated]
# Index: []

# %%
plt.hist(df["Power Generated"])
# Out:
# (array([1830.,  179.,  134.,  106.,  121.,  175.,  106.,  109.,   85.,
#           75.]),
#  array([    0.,  3658.,  7316., 10974., 14632., 18290., 21948., 25606.,
#         29264., 32922., 36580.]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df["Average Temperature (Day)"])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df["Distance to Solar Noon"])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df["Average Wind Direction (Day)"])
# Out:
# <AxesSubplot:>

# %%
df["Sky Cover"].value_counts()
# Out:
# 1    776
# 4    598
# 3    580
# 0    518
# 2    448
# Name: Sky Cover, dtype: int64

# %%
sns.boxplot(df["Relative Humidity"])
# Out:
# <AxesSubplot:>

# %%
corr_matrix=df.corr()
fig,ax=plt.subplots(figsize=(12,12))
ax=sns.heatmap(corr_matrix,annot=True,linewidths=0.5,fmt=".2f")

# %%
'''Removing highly correlated columns like 

"Day of Year" is highly correlated with "Year" and "Month" hence I will remove "Day of Year"
"Distance to Solar Noon" and "Is Daylight"

'''
df.drop("Day of Year",axis=1,inplace=True)
df.drop("Distance to Solar Noon",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Year  Month  Day  First Hour of Period  Is Daylight  \
# 0  2008      9    1                     1        False
# 1  2008      9    1                     4        False
# 2  2008      9    1                     7         True
# 3  2008      9    1                    10         True
# 4  2008      9    1                    13         True
#
#    Average Temperature (Day)  Average Wind Direction (Day)  \
# 0                         69                            28
# 1                         69                            28
# 2                         69                            28
# 3                         69                            28
# 4                         69                            28
#
#    Average Wind Speed (Day)  Sky Cover  Visibility  Relative Humidity  \
# 0                       7.5          0        10.0                 75
# 1                       7.5          0        10.0                 77
# 2                       7.5          0        10.0                 70
# 3                       7.5          0        10.0                 33
# 4                       7.5          0        10.0                 21
#
#    Average Wind Speed (Period)  Average Barometric Pressure (Period)  \
# 0                          8.0                                 29.82
# 1                          5.0                                 29.85
# 2                          0.0                                 29.89
# 3                          0.0                                 29.91
# 4                          3.0                                 29.89
#
#    Power Generated
# 0                0
# 1                0
# 2             5418
# 3            25477
# 4            30069

# %% [markdown]
# ## Train and Test splitting

# %%
X=df.drop("Power Generated",axis=1)
y=df["Power Generated"]

# %%
'''Splitting data into train and test split of 8:2'''
train_size=round(0.7*len(df))
val_size=round(train_size+0.15*len(df))

'''
Splitting with train_test_split function won't work here as it shuffles the data before splitting but we avoid that in 
time series dataset
'''
X_train,y_train=X[:train_size],y[:train_size]
X_val,y_val=X[train_size:val_size],y[train_size:val_size]
X_test,y_test=X[val_size:],y[val_size:]

# %%
'''just checking if splitting is done correctly'''

X_train.shape,y_train.shape,X_val.shape,y_val.shape,X_test.shape,y_test.shape
# Out:
# ((2044, 13), (2044,), (438, 13), (438,), (438, 13), (438,))

# %% [markdown]
# ## Filling missing data in train,test and validation set

# %% [markdown]
# ### Train set

# %%
X_train.isna().sum()
# Out:
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             1
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
'''Filling average wind column's missing value with mean of the column'''

X_train["Average Wind Speed (Period)"].fillna(X_train["Average Wind Speed (Period)"].median(),inplace=True)
X_train.isna().sum()
# Out:
# C:\Users\ashis\OneDrive\Desktop\MLProjects\Internship_Project1\env\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
y_train.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Validation set

# %%
X_val.isna().sum()
# Out:
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
y_val.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Test Set

# %%
X_test.isna().sum()
# Out:
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
y_test.isna().sum()
# Out:
# 0

# %% [markdown]
# # Step 2. Modelling & Evaluation

# %%
'''Custom evaluation function'''

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def model_score(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)  # Mean Absolute Error
    mse = mean_squared_error(y_true, y_pred)  # Mean Squared Error
    rmse = np.sqrt(mse)  # Root Mean Squared Error
    r2 = r2_score(y_true, y_pred)  # R-squared (Coefficient of Determination)
    
    print("Mean Absolute Error (MAE):", mae)
    print("Mean Squared Error (MSE):", mse)
    print("Root Mean Squared Error (RMSE):", rmse)
    print("R-squared (R2):", r2)

# %%
'''Applying Linear Regression model to dataset'''
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

y_pred_lr=model.predict(X_val)
model_score(y_val,y_pred_lr)
# Out:
# Mean Absolute Error (MAE): 7643.982685578311
# Mean Squared Error (MSE): 88382785.3865175
# Root Mean Squared Error (RMSE): 9401.211910520766
# R-squared (R2): 0.39246071214312606

# %%
'''Applying RandomForestRegressor to dataset'''
from sklearn.ensemble import RandomForestRegressor

model2 = RandomForestRegressor(n_estimators=100, random_state=42,n_jobs=-1)
model2.fit(X_train, y_train)
y_pred_rf=model2.predict(X_val)
model_score(y_val,y_pred_rf)
# Out:
# Mean Absolute Error (MAE): 2858.3535844748862
# Mean Squared Error (MSE): 19164941.857783336
# Root Mean Squared Error (RMSE): 4377.778187366662
# R-squared (R2): 0.8682610524529559

# %% [markdown]
# # Hyper Parameter Tuning of RandomForestRegressor

# %% [markdown]
# ### We will use Randomized Search CV to find best values of hyperparameters
#
# #### Adjusting the following hyper parameters
# * max_depth
# * min_samples_leaf
# * min_samples_split
# * n_estimators

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

grid = {
    "n_estimators": [10, 100, 200, 500, 1000, 1200],
    "max_depth": [None, 5, 10, 20, 30],
    "min_samples_split": [2, 4, 6],
    "min_samples_leaf": [1, 2, 4]
}

rf = RandomForestRegressor(n_jobs=-1)
rs = RandomizedSearchCV(estimator=rf, param_distributions=grid, n_iter=20, cv=5)

rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1), n_iter=20,
#                    param_distributions={'max_depth': [None, 5, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 4, 6],
#                                         'n_estimators': [10, 100, 200, 500,
#                                                          1000, 1200]})

# %%
rs.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_depth': 20}

# %%
rs_y_pred=rs.predict(X_val)

# %%
model_score(y_val,rs_y_pred)
# Out:
# Mean Absolute Error (MAE): 2832.8975069065577
# Mean Squared Error (MSE): 18995198.300838012
# Root Mean Squared Error (RMSE): 4358.34811606852
# R-squared (R2): 0.8694278620217408

# %% [markdown]
# # RNN (Recurrent Neural Network)

# %% [markdown]
# Using LSTM Training Block

# %%
import tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Step 1: Scale the input features
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Scale the target variable using a separate scaler
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.values.reshape(-1, 1))

# Step 3: Create sequences
def create_sequences(X, y, seq_len):
    Xs, ys = [], []
    for i in range(len(X) - seq_len):
        Xs.append(X[i:i+seq_len])
        ys.append(y[i+seq_len])
    return np.array(Xs), np.array(ys)

SEQ_LEN = 60
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, SEQ_LEN)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, SEQ_LEN)

# %%
model_rnn = Sequential()
model_rnn.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
model_rnn.add(LSTM(32, activation='relu'))
model_rnn.add(Dense(1))
model_rnn.compile(optimizer='adam', loss='mse')

model_rnn.fit(X_train_seq, y_train_seq, epochs=50, batch_size=32, validation_data=(X_test_seq, y_test_seq))
# Out:
# Epoch 1/50
# 62/62 [==============================] - 6s 47ms/step - loss: 0.0635 - val_loss: 0.1014
# Epoch 2/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0540 - val_loss: 0.0916
# Epoch 3/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0451 - val_loss: 0.0750
# Epoch 4/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.0297 - val_loss: 0.0451
# Epoch 5/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0250 - val_loss: 0.0313
# Epoch 6/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0229 - val_loss: 0.0301
# Epoch 7/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0196 - val_loss: 0.0246
# Epoch 8/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0153 - val_loss: 0.0173
# Epoch 9/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0129 - val_loss: 0.0120
# Epoch 10/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0112 - val_loss: 0.0236
# Epoch 11/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0101 - val_loss: 0.0165
# Epoch 12/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0105 - val_loss: 0.0221
# Epoch 13/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0096 - val_loss: 0.0166
# Epoch 14/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0090 - val_loss: 0.0202
# Epoch 15/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0091 - val_loss: 0.0128
# Epoch 16/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0080 - val_loss: 0.0183
# Epoch 17/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0082 - val_loss: 0.0157
# Epoch 18/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0081 - val_loss: 0.0139
# Epoch 19/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0074 - val_loss: 0.0127
# Epoch 20/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0081 - val_loss: 0.0185
# Epoch 21/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0072 - val_loss: 0.0199
# Epoch 22/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0067 - val_loss: 0.0178
# Epoch 23/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0070 - val_loss: 0.0143
# Epoch 24/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0069 - val_loss: 0.0203
# Epoch 25/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0074 - val_loss: 0.0131
# Epoch 26/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0060 - val_loss: 0.0214
# Epoch 27/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0061 - val_loss: 0.0192
# Epoch 28/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0066 - val_loss: 0.0255
# Epoch 29/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0066 - val_loss: 0.0184
# Epoch 30/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0055 - val_loss: 0.0146
# Epoch 31/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0052 - val_loss: 0.0203
# Epoch 32/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0047 - val_loss: 0.0194
# Epoch 33/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0049 - val_loss: 0.0157
# Epoch 34/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0048 - val_loss: 0.0147
# Epoch 35/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0046 - val_loss: 0.0186
# Epoch 36/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0047 - val_loss: 0.0119
# Epoch 37/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0043 - val_loss: 0.0170
# Epoch 38/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.0039 - val_loss: 0.0193
# Epoch 39/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0040 - val_loss: 0.0182
# Epoch 40/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0039 - val_loss: 0.0238
# Epoch 41/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0038 - val_loss: 0.0197
# Epoch 42/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0036 - val_loss: 0.0154
# Epoch 43/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0038 - val_loss: 0.0189
# Epoch 44/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0037 - val_loss: 0.0137
# Epoch 45/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0034 - val_loss: 0.0158
# Epoch 46/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0036 - val_loss: 0.0151
# Epoch 47/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0035 - val_loss: 0.0155
# Epoch 48/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0034 - val_loss: 0.0135
# Epoch 49/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0032 - val_loss: 0.0145
# Epoch 50/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0031 - val_loss: 0.0205

# %% [markdown]
# Training

# %% [markdown]
# Prediction and Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# %%
y_pred_rnn = model_rnn.predict(X_test_seq)
y_pred_rnn_inv = y_scaler.inverse_transform(y_pred_rnn)
y_test_seq_inv = y_scaler.inverse_transform(y_test_seq.reshape(-1,1))

rmse_rnn = np.sqrt(mean_squared_error(y_test_seq_inv, y_pred_rnn_inv))
mae_rnn = mean_absolute_error(y_test_seq_inv, y_pred_rnn_inv)
r2_rnn = r2_score(y_test_seq_inv, y_pred_rnn_inv)

print("Root Mean Squared Error is : ", rmse_rnn)
print("Mean Absolute Error is : ", mae_rnn)
print("R2 Score is : ", r2_rnn)
# Out:
# 12/12 [==============================] - 1s 14ms/step
# Root Mean Squared Error is :  5239.150213099121
# Mean Absolute Error is :  3140.3333102281763
# R2 Score is :  0.8031833214093622

# %%
model_rnn = Sequential()
model_rnn.add(LSTM(64, return_sequences=True, activation='tanh', input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
model_rnn.add(LSTM(32, activation='tanh'))
model_rnn.add(Dense(1))
model_rnn.compile(optimizer='adam', loss='mse')

model_rnn.fit(X_train_seq, y_train_seq, epochs=50, batch_size=32, validation_data=(X_test_seq, y_test_seq))
# Out:
# Epoch 1/50
# 62/62 [==============================] - 8s 58ms/step - loss: 0.0611 - val_loss: 0.0942
# Epoch 2/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0466 - val_loss: 0.0545
# Epoch 3/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0291 - val_loss: 0.0301
# Epoch 4/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0202 - val_loss: 0.0237
# Epoch 5/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0137 - val_loss: 0.0191
# Epoch 6/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0127 - val_loss: 0.0156
# Epoch 7/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0101 - val_loss: 0.0127
# Epoch 8/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0092 - val_loss: 0.0135
# Epoch 9/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0085 - val_loss: 0.0153
# Epoch 10/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0089 - val_loss: 0.0141
# Epoch 11/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0085 - val_loss: 0.0178
# Epoch 12/50
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0088 - val_loss: 0.0144
# Epoch 13/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0079 - val_loss: 0.0149
# Epoch 14/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0074 - val_loss: 0.0142
# Epoch 15/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.0078 - val_loss: 0.0167
# Epoch 16/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0071 - val_loss: 0.0178
# Epoch 17/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0066 - val_loss: 0.0193
# Epoch 18/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0067 - val_loss: 0.0186
# Epoch 19/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0075 - val_loss: 0.0143
# Epoch 20/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0064 - val_loss: 0.0115
# Epoch 21/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0062 - val_loss: 0.0130
# Epoch 22/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0060 - val_loss: 0.0197
# Epoch 23/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0057 - val_loss: 0.0140
# Epoch 24/50
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0053 - val_loss: 0.0149
# Epoch 25/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0053 - val_loss: 0.0142
# Epoch 26/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0051 - val_loss: 0.0150
# Epoch 27/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0048 - val_loss: 0.0169
# Epoch 28/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0047 - val_loss: 0.0163
# Epoch 29/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0045 - val_loss: 0.0171
# Epoch 30/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0039 - val_loss: 0.0126
# Epoch 31/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0042 - val_loss: 0.0172
# Epoch 32/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0041 - val_loss: 0.0144
# Epoch 33/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0042 - val_loss: 0.0126
# Epoch 34/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0033 - val_loss: 0.0140
# Epoch 35/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0034 - val_loss: 0.0119
# Epoch 36/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0036 - val_loss: 0.0150
# Epoch 37/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0029 - val_loss: 0.0119
# Epoch 38/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0029 - val_loss: 0.0145
# Epoch 39/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0031 - val_loss: 0.0167
# Epoch 40/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0029 - val_loss: 0.0155
# Epoch 41/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0027 - val_loss: 0.0160
# Epoch 42/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0027 - val_loss: 0.0151
# Epoch 43/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0027 - val_loss: 0.0132
# Epoch 44/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0025 - val_loss: 0.0158
# Epoch 45/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0027 - val_loss: 0.0169
# Epoch 46/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0026 - val_loss: 0.0124
# Epoch 47/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.0022 - val_loss: 0.0140
# Epoch 48/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0028 - val_loss: 0.0111
# Epoch 49/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.0021 - val_loss: 0.0151
# Epoch 50/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.0020 - val_loss: 0.0116

# %%
y_pred_rnn = model_rnn.predict(X_test_seq)
y_pred_rnn_inv = y_scaler.inverse_transform(y_pred_rnn)
y_test_seq_inv = y_scaler.inverse_transform(y_test_seq.reshape(-1,1))

rmse_rnn = np.sqrt(mean_squared_error(y_test_seq_inv, y_pred_rnn_inv))
mae_rnn = mean_absolute_error(y_test_seq_inv, y_pred_rnn_inv)
r2_rnn = r2_score(y_test_seq_inv, y_pred_rnn_inv)

print("Root Mean Squared Error is : ", rmse_rnn)
print("Mean Absolute Error is : ", mae_rnn)
print("R2 Score is : ", r2_rnn)
# Out:
# 12/12 [==============================] - 1s 14ms/step
# Root Mean Squared Error is :  3940.3117443338792
# Mean Absolute Error is :  2219.801343453624
# R2 Score is :  0.8886727800736138

# %% [markdown]
# # Saving model

# %%
# model_rnn.save("rnn_model.h5")
