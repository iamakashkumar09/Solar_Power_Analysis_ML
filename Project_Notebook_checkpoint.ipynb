# %% [markdown]
# <a href="https://colab.research.google.com/github/iamakashkumar09/Solar_Power_Analysis_ML/blob/main/Project_Notebook_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solar Power Generation analysis
#
# ## Team Members
# ### 1.Ashish Chauhan
# ### 2.Akash Kumar Gaud
# ### 3.Anish Chauhan
# ### 4.Ashish Gautam
# ### 5.Aryan Shrikant Jadhao

# %% [markdown]
# # Step 1. Data importing and preprocessing

# %%
import pandas as pd
#import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#imported the csv file

df=pd.read_csv("powerPlantDataBerkeley.csv")
df.head(10)
# Out:
#    Day of Year  Year  Month  Day  First Hour of Period  Is Daylight  \
# 0          245  2008      9    1                     1        False
# 1          245  2008      9    1                     4        False
# 2          245  2008      9    1                     7         True
# 3          245  2008      9    1                    10         True
# 4          245  2008      9    1                    13         True
# 5          245  2008      9    1                    16         True
# 6          245  2008      9    1                    19         True
# 7          245  2008      9    1                    22        False
# 8          246  2008      9    2                     1        False
# 9          246  2008      9    2                     4        False
#
#    Distance to Solar Noon  Average Temperature (Day)  \
# 0                0.859897                         69
# 1                0.628535                         69
# 2                0.397172                         69
# 3                0.165810                         69
# 4                0.065553                         69
# 5                0.296915                         69
# 6                0.528278                         69
# 7                0.759640                         69
# 8                0.862113                         72
# 9                0.630155                         72
#
#    Average Wind Direction (Day)  Average Wind Speed (Day)  Sky Cover  \
# 0                            28                       7.5          0
# 1                            28                       7.5          0
# 2                            28                       7.5          0
# 3                            28                       7.5          0
# 4                            28                       7.5          0
# 5                            28                       7.5          0
# 6                            28                       7.5          0
# 7                            28                       7.5          0
# 8                            29                       6.8          0
# 9                            29                       6.8          0
#
#    Visibility  Relative Humidity  Average Wind Speed (Period)  \
# 0        10.0                 75                          8.0
# 1        10.0                 77                          5.0
# 2        10.0                 70                          0.0
# 3        10.0                 33                          0.0
# 4        10.0                 21                          3.0
# 5        10.0                 20                         23.0
# 6        10.0                 36                         15.0
# 7        10.0                 49                          6.0
# 8        10.0                 67                          6.0
# 9        10.0                 49                          0.0
#
#    Average Barometric Pressure (Period)  Power Generated
# 0                                 29.82                0
# 1                                 29.85                0
# 2                                 29.89             5418
# 3                                 29.91            25477
# 4                                 29.89            30069
# 5                                 29.85            16280
# 6                                 29.83              515
# 7                                 29.86                0
# 8                                 29.86                0
# 9                                 29.87                0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Day of Year                           2920 non-null   int64
#  1   Year                                  2920 non-null   int64
#  2   Month                                 2920 non-null   int64
#  3   Day                                   2920 non-null   int64
#  4   First Hour of Period                  2920 non-null   int64
#  5   Is Daylight                           2920 non-null   bool
#  6   Distance to Solar Noon                2920 non-null   float64
#  7   Average Temperature (Day)             2920 non-null   int64
#  8   Average Wind Direction (Day)          2920 non-null   int64
#  9   Average Wind Speed (Day)              2920 non-null   float64
#  10  Sky Cover                             2920 non-null   int64
#  11  Visibility                            2920 non-null   float64
#  12  Relative Humidity                     2920 non-null   int64
#  13  Average Wind Speed (Period)           2919 non-null   float64
#  14  Average Barometric Pressure (Period)  2920 non-null   float64
#  15  Power Generated                       2920 non-null   int64
# dtypes: bool(1), float64(5), int64(10)
# memory usage: 345.2 KB

# %% [markdown]
# * As clearly visible the dataset is a time series dataset but I didn't sort it because it was already sorted.
# * Secondly there are no columns with object type values hence there was no need of converting any column to pandas category and assigning the codes back to column to convert object type column to numeric type

# %%
X=df.drop("Power Generated",axis=1)
y=df["Power Generated"]

# %%
'''Splitting data into train and test split of 8:2'''
train_size=round(0.7*len(df))
val_size=round(train_size+0.15*len(df))

'''
Splitting with train_test_split function won't work here as it shuffles the data before splitting but we avoid that in
time series dataset
'''
X_train,y_train=X[:train_size],y[:train_size]
X_val,y_val=X[train_size:val_size],y[train_size:val_size]
X_test,y_test=X[val_size:],y[val_size:]

# %%
'''just checking if splitting is done correctly'''

X_train.shape,y_train.shape,X_val.shape,y_val.shape,X_test.shape,y_test.shape
# Out:
# ((2044, 15), (2044,), (438, 15), (438,), (438, 15), (438,))

# %% [markdown]
# ## Filling missing data in train,test and validation set

# %% [markdown]
# ### Train set

# %%
X_train.isna().sum()
# Out:
# Day of Year                             0
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Distance to Solar Noon                  0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             1
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
'''Filling average wind column's missing value with mean of the column'''

X_train["Average Wind Speed (Period)"].fillna(X_train["Average Wind Speed (Period)"].mean(),inplace=True)
X_train.isna().sum()
# Out:
# <ipython-input-58-d944b38dd9b8>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train["Average Wind Speed (Period)"].fillna(X_train["Average Wind Speed (Period)"].mean(),inplace=True)
# <ipython-input-58-d944b38dd9b8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["Average Wind Speed (Period)"].fillna(X_train["Average Wind Speed (Period)"].mean(),inplace=True)
# Day of Year                             0
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Distance to Solar Noon                  0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Validation set

# %%
X_val.isna().sum()
# Out:
# Day of Year                             0
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Distance to Solar Noon                  0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
y_val.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Test Set

# %%
X_test.isna().sum()
# Out:
# Day of Year                             0
# Year                                    0
# Month                                   0
# Day                                     0
# First Hour of Period                    0
# Is Daylight                             0
# Distance to Solar Noon                  0
# Average Temperature (Day)               0
# Average Wind Direction (Day)            0
# Average Wind Speed (Day)                0
# Sky Cover                               0
# Visibility                              0
# Relative Humidity                       0
# Average Wind Speed (Period)             0
# Average Barometric Pressure (Period)    0
# dtype: int64

# %%
y_test.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Step 2. Modelling & Evaluation

# %%
'''Custom evaluation function'''

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def model_score(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)  # Mean Absolute Error
    mse = mean_squared_error(y_true, y_pred)  # Mean Squared Error
    rmse = np.sqrt(mse)  # Root Mean Squared Error
    r2 = r2_score(y_true, y_pred)  # R-squared (Coefficient of Determination)

    print("Mean Absolute Error (MAE):", mae)
    print("Mean Squared Error (MSE):", mse)
    print("Root Mean Squared Error (RMSE):", rmse)
    print("R-squared (R2):", r2)

# %%
'''Applying Linear Regression model to dataset'''
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

y_pred_lr=model.predict(X_val)
model_score(y_val,y_pred_lr)
# Out:
# Mean Absolute Error (MAE): 5360.079473889911
# Mean Squared Error (MSE): 47638662.99099366
# Root Mean Squared Error (RMSE): 6902.076715814861
# R-squared (R2): 0.6725339752370265

# %%
'''Applying RandomForestRegressor to dataset'''
from sklearn.ensemble import RandomForestRegressor

model2 = RandomForestRegressor(n_estimators=100, random_state=42,n_jobs=-1)
model2.fit(X_train, y_train)
y_pred_rf=model2.predict(X_val)
model_score(y_val,y_pred_rf)
# Out:
# Mean Absolute Error (MAE): 2378.5115753424657
# Mean Squared Error (MSE): 17880027.144984704
# Root Mean Squared Error (RMSE): 4228.4781121562755
# R-squared (R2): 0.87709349834337

# %% [markdown]
# # Hyper Parameter Tuning of RandomForestRegressor

# %% [markdown]
# ### We will use Randomized Search CV to find best values of hyperparameters
#
# #### Adjusting the following hyper parameters
# * max_depth
# * min_samples_leaf
# * min_samples_split
# * n_estimators

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

grid = {
    "n_estimators": [10, 100, 200, 500, 1000, 1200],
    "max_depth": [None, 5, 10, 20, 30],
    "min_samples_split": [2, 4, 6],
    "min_samples_leaf": [1, 2, 4]
}

rf = RandomForestRegressor(n_jobs=-1)
rs = RandomizedSearchCV(estimator=rf, param_distributions=grid, n_iter=20, cv=5)

rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1), n_iter=20,
#                    param_distributions={'max_depth': [None, 5, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 4, 6],
#                                         'n_estimators': [10, 100, 200, 500,
#                                                          1000, 1200]})

# %%
rs.best_params_
# Out:
# {'n_estimators': 1200,
#  'min_samples_split': 4,
#  'min_samples_leaf': 2,
#  'max_depth': 30}

# %%
rs_y_pred=rs.predict(X_val)

# %%
model_score(y_val,rs_y_pred)
# Out:
# Mean Absolute Error (MAE): 2359.3946135323804
# Mean Squared Error (MSE): 17343161.050679874
# Root Mean Squared Error (RMSE): 4164.512102357235
# R-squared (R2): 0.8807838917065353

# %% [markdown]
# # RNN (Recurrent Neural Network)

# %% [markdown]
# Using LSTM Training Block

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Step 1: Scale the input features
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Scale the target variable using a separate scaler
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.values.reshape(-1, 1))

# Step 3: Create sequences
def create_sequences(X, y, seq_len):
    Xs, ys = [], []
    for i in range(len(X) - seq_len):
        Xs.append(X[i:i+seq_len])
        ys.append(y[i+seq_len])
    return np.array(Xs), np.array(ys)

SEQ_LEN = 60
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, SEQ_LEN)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test_scaled, SEQ_LEN)

# %%
model_rnn = Sequential()
model_rnn.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
model_rnn.add(LSTM(32, activation='relu'))
model_rnn.add(Dense(1))
model_rnn.compile(optimizer='adam', loss='mse')

model_rnn.fit(X_train_seq, y_train_seq, epochs=50, batch_size=32, validation_data=(X_test_seq, y_test_seq))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - loss: 0.0630 - val_loss: 0.1001
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0589 - val_loss: 0.0721
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0315 - val_loss: 0.0287
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0208 - val_loss: 0.0193
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0151 - val_loss: 0.0261
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0117 - val_loss: 0.0282
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0110 - val_loss: 0.0134
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0098 - val_loss: 0.0162
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0089 - val_loss: 0.0118
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0078 - val_loss: 0.0110
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0077 - val_loss: 0.0119
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0067 - val_loss: 0.0103
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0072 - val_loss: 0.0130
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0072 - val_loss: 0.0130
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0067 - val_loss: 0.0104
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0068 - val_loss: 0.0151
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0059 - val_loss: 0.0126
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0058 - val_loss: 0.0241
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0063 - val_loss: 0.0131
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0049 - val_loss: 0.0148
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0052 - val_loss: 0.0139
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0062 - val_loss: 0.0163
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0052 - val_loss: 0.0123
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0043 - val_loss: 0.0148
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - val_loss: 0.0172
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - val_loss: 0.0409
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0041 - val_loss: 0.0168
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0036 - val_loss: 0.0173
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0040 - val_loss: 0.0159
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - val_loss: 0.0205
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0044 - val_loss: 0.0127
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0036 - val_loss: 0.0166
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0032 - val_loss: 0.0159
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0032 - val_loss: 0.0149
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0032 - val_loss: 0.0140
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0034 - val_loss: 0.0148
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - val_loss: 0.0192
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0034 - val_loss: 0.0189
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0030 - val_loss: 0.0150
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0023 - val_loss: 0.0179
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0028 - val_loss: 0.0200
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0035 - val_loss: 0.0136
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0024 - val_loss: 0.0143
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0027 - val_loss: 0.0138
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0022 - val_loss: 0.0138
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0024 - val_loss: 0.0134
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0024 - val_loss: 0.0150
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0023 - val_loss: 0.0121
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - val_loss: 0.0184
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026 - val_loss: 0.0133

# %% [markdown]
# Training

# %% [markdown]
# Prediction and Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# %%
y_pred_rnn = model_rnn.predict(X_test_seq)
y_pred_rnn_inv = y_scaler.inverse_transform(y_pred_rnn)
y_test_seq_inv = y_scaler.inverse_transform(y_test_seq.reshape(-1,1))

rmse_rnn = np.sqrt(mean_squared_error(y_test_seq_inv, y_pred_rnn_inv))
mae_rnn = mean_absolute_error(y_test_seq_inv, y_pred_rnn_inv)
r2_rnn = r2_score(y_test_seq_inv, y_pred_rnn_inv)

print("Root Mean Squared Error is : ", rmse_rnn)
print("Mean Absolute Error is : ", mae_rnn)
print("R2 Score is : ", r2_rnn)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step
# Root Mean Squared Error is :  4219.696924809542
# Mean Absolute Error is :  2253.4948587058084
# R2 Score is :  0.8723259260721012

# %%
model_rnn = Sequential()
model_rnn.add(LSTM(64, return_sequences=True, activation='tanh', input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
model_rnn.add(LSTM(32, activation='tanh'))
model_rnn.add(Dense(1))
model_rnn.compile(optimizer='adam', loss='mse')

model_rnn.fit(X_train_seq, y_train_seq, epochs=50, batch_size=32, validation_data=(X_test_seq, y_test_seq))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0671 - val_loss: 0.0927
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0499 - val_loss: 0.0373
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0229 - val_loss: 0.0247
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0192 - val_loss: 0.0187
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0126 - val_loss: 0.0188
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0119 - val_loss: 0.0213
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0088 - val_loss: 0.0124
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0093 - val_loss: 0.0126
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0087 - val_loss: 0.0138
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0102 - val_loss: 0.0156
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0108 - val_loss: 0.0141
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0084 - val_loss: 0.0117
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0083 - val_loss: 0.0124
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0069 - val_loss: 0.0129
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0079 - val_loss: 0.0104
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0063 - val_loss: 0.0106
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0063 - val_loss: 0.0098
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0070 - val_loss: 0.0123
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0069 - val_loss: 0.0118
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0051 - val_loss: 0.0113
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0061 - val_loss: 0.0121
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0050 - val_loss: 0.0100
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0055 - val_loss: 0.0099
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0055 - val_loss: 0.0115
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0048 - val_loss: 0.0094
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0060 - val_loss: 0.0121
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0049 - val_loss: 0.0100
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0039 - val_loss: 0.0134
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0042 - val_loss: 0.0129
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0039 - val_loss: 0.0110
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0041 - val_loss: 0.0118
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0037 - val_loss: 0.0109
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0035 - val_loss: 0.0120
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0035 - val_loss: 0.0125
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0040 - val_loss: 0.0100
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0038 - val_loss: 0.0106
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0029 - val_loss: 0.0096
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0028 - val_loss: 0.0110
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0032 - val_loss: 0.0161
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0026 - val_loss: 0.0098
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0025 - val_loss: 0.0120
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0028 - val_loss: 0.0106
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0027 - val_loss: 0.0131
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0027 - val_loss: 0.0118
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0025 - val_loss: 0.0103
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023 - val_loss: 0.0096
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 0.0113
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0025 - val_loss: 0.0123
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 0.0126
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022 - val_loss: 0.0128

# %%
y_pred_rnn = model_rnn.predict(X_test_seq)
y_pred_rnn_inv = y_scaler.inverse_transform(y_pred_rnn)
y_test_seq_inv = y_scaler.inverse_transform(y_test_seq.reshape(-1,1))

rmse_rnn = np.sqrt(mean_squared_error(y_test_seq_inv, y_pred_rnn_inv))
mae_rnn = mean_absolute_error(y_test_seq_inv, y_pred_rnn_inv)
r2_rnn = r2_score(y_test_seq_inv, y_pred_rnn_inv)

print("Root Mean Squared Error is : ", rmse_rnn)
print("Mean Absolute Error is : ", mae_rnn)
print("R2 Score is : ", r2_rnn)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Root Mean Squared Error is :  4135.125387621591
# Mean Absolute Error is :  2240.1780212430094
# R2 Score is :  0.8773923513296682
